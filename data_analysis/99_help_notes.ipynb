# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data.csv', index_col=0, dtype={'CP':str})
df.columns = df.columns.str.lower()
df['update'] = pd.to_datetime(df['update'], format='%M:%S.%f').dt.time

# %% [markdown]
# # IDs

# %%
df['id'].quantile([0,.25,.5,.75,1])

df['id'].min()

df['id'].max()

df['id'].unique()

len(df['id'].unique()) # the IDs are not continous. Some are missing

ids = df['id'].unique()

np.quantile(ids, [0,.25,.5,.75,1])

# %% [markdown]
# # UPDATE

# %%
df['update'].min()

df['update'].max()

# It makes no sense to analyze the column 'update' since its values range from minute 0  to minute 59.

df['update_minute'] = pd.to_datetime(df['update'], errors='coerce', format='%H:%M:%S.%f').dt.minute

df['update_minute']

g = sns.catplot(kind='count', data=df, x='update_minute', row='status')

g.set(xticks=range(0,61,10))
g.set_xticklabels(range(0,61,10))

None
